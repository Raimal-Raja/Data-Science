# %% [markdown]
# ### Delete Rows/Columns
# This methods we commonly used to handle missing values. Rows can be deleted if if has insignificant number of missing value columns cab be delete if has more than 75% of missing value
