# %% [markdown]
# ## Type of Sampling Technique
# - Probability sampling
#     - Random
#     - Systematic
#     - Stratified
#     - Cluster
# - Non-Probability sampling
#     - Convenience
#     - Purposive
#     - Voluntary response
#     - Snowball
