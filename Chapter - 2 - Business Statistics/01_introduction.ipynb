# %% [markdown]
# ### Statistics
# - Basically, The statistical analysis is meant to collect and study, the information availabe in large quantites
#
# - Statistics is a branch of mathematics, where computation is done over a bulk of data using charts, table, graphs etc.
#
# - The data collected for analysis here is called measurements. Now, if we have to measure the data based on a scenario, a sample is taken out of a population.
#
# - Then the analysis or calculation is done for the following meaurement.
