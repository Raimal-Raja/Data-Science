# %% [markdown]
# ## Population and  Sample
# ### Population
# The universe of objects that is required to be analysed is known as population.
#
# ### Sample
# The subset of population is known as sample. The specific group of individuals that you will collect data from the populations is known as sample.
