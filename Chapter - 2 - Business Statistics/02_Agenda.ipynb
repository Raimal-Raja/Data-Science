# %% [markdown]
# ## Agenda
# - Types of Statistics
# - Descriptive Statistics
# - Inferential Statistics
# - Types of Data (Which are majorly categorical and numerical, otherwise known as qualative and quantative data)
