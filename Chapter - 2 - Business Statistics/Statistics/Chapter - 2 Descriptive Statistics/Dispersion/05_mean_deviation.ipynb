# %% [markdown]
# ### Mean Deviation
# - Average sum of the absolute values of the deviation from any arbitrary values, e.g mean, median, mode, etc.
# - Suggested  to calculate from median because its give least when measured from the median.
# - The deviation of an  observation xi from the assumed mean.
#     - A is define as (xi -A)
# - Therefore, the mean deviation can be defined as
#
# ![image.png](attachment:image.png)
