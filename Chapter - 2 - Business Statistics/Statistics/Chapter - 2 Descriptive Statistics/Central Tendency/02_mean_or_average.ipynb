# %% [markdown]
# ## Mean/Average
# An average set of obersvation of the data. It compute the sum of all observation present in the datasets divided by total number of observation.
#
# ## Mean
# - Add/Sum each number/observation present in the dataset.
# - Calculate the total number present in the dataset.
# - Divide sum of observation to the total number of observation
#
# ![image.png](attachment:image.png)
