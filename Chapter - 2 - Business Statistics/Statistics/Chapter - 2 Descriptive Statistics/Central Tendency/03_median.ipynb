# %% [markdown]
# ## Median
# - 1 The Middle Number
# - 2 Found by ordering all the data points and picking out the one in the middle
# - 3 If there are two middle numbers, taking the mean of those two numbers

# %% [markdown]
# ![image.png](attachment:image.png)
