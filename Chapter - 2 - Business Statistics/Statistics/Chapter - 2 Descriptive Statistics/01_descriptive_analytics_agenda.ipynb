# %% [markdown]
# ### Agenda
# - Measure of Central Tendency
#     - Mean
#     - Median
#     - Mode
# - Measure of Dispersion
#     - Range
#     - IQR
#     - Variance
#     - standard deviation
#     - Mean deviation
