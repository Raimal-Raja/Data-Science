# %% [markdown]
# ### Why n-1 & why not n?
# - This is actually called as Bessel's correction
#
# - This Method corrects the  bias in the estimation of the population varience
#
# - It also partially corrects the bias in the estimation of the population standard deviation
#
# - The idea behind this is that this is a more unbiased measure of variance than the usual definition

# %% [markdown]
# #### Image having a huge bookself.
# Let say, the total thickness of the first 6 books turns out to be 158mm. This means that the mean thickness of a book based on firt  6 samples is 26.3

# %% [markdown]
# ![image.png](attachment:image.png)
