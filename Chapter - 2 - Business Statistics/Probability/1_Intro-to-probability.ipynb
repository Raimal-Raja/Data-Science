# %% [markdown]
# ### Probability

# %% [markdown]
# If the trail is repeated number of times under homogenous and identical condition then the value of ratio of number of favourable cases to  the total number of possible cases is called probabilty

# %% [markdown]
# probability = no of favourable coutcome devided by total number of possible outcome
