# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
churn_df = pd.read_csv(r'D:\GitHub\Data-Science\Python For Data Science\datasets\Churn_Modelling.csv')
# print(dataset.head(5))

churn_df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
churn_df.Geography.value_counts().plot.pie(y='Geography', figsize=(5,5))
# Out:
# <Axes: ylabel='count'>

# %%
churn_df.Geography.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Geography'>

# %%
churn_df.Exited.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
# Total percentage of people  who  have left the company
churn_df.Exited.value_counts()/len(churn_df)*100
# Out:
# Exited
# 0    79.63
# 1    20.37
# Name: count, dtype: float64

# %%
plt.bar(churn_df['Geography'], churn_df['EstimatedSalary'].mean(), color='cyan', edgecolor='orange')
plt.title('Geography vs Estimated Salary')
plt.show()

# %%
label_ex = 'JavaScript', 'Java', 'Python', 'R'
sizes = [15,30,45,10]
explode_labels = (0,0.5,0,0)
fig1, ex1 = plt.subplots()

ex1.pie(sizes, explode=explode_labels, labels =label_ex,shadow=True, startangle=90 )
ex1.axis('equal')
plt.show()
