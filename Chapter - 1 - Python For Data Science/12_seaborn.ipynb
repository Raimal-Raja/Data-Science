# %% [markdown]
# ## Seaborn
# It is summerized that if Matplotlib "Tries to make easy things and hard things possible" "Seaborn tries to make a well-defined set of hard things easy too".

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Seaborn for  plotting and styling
import seaborn as sns
# df = sns.load_dataset(r"D:\GitHub\Data-Science\Python For Data Science\datasets\iris.csv")
# print(df.head())

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.plot(kind='barh')
# Out:
# <Axes: >

# %%
df.species.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='species'>

# %%
sns.kdeplot(df['sepal_length'], shade=True)
# Out:
# C:\Users\Professor\AppData\Local\Temp\ipykernel_1768\3648197333.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_length'], shade=True)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(df['sepal_length'])
# Out:
# C:\Users\Professor\AppData\Local\Temp\ipykernel_1768\537145680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.pairplot(df, hue='species', size=3)
# Out:
# d:\GitHub\Data-Science\.venv\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
