# %% [markdown]
# ## Primary Key
# a primary key is used to ensure data in the specific column is unique and not null
#
# ## Foreign Key
# a froeign key is a column or group of columns in a relational database table that provides a link between data in  two tables. it is a column (for columns) that references a column (most often that primary key) of another table
#
# correspond to the values of primary key in another table
