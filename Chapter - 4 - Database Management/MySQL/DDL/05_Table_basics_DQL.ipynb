# %% [markdown]
# ## DQL
# DQL statements are used for perfoming queries on the data within schema objects. The purpose of the DQL commands is to get some schema relation based on the query passed to it
