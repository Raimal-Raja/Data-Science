# %% [markdown]
# ## Tokenization in NLP
# ### Topics
# - Corpus - Paragraph
# - Documents - Sentence
# - Vocabulary - count off all the Unique words
# - Words - words in paragraph

# %% [markdown]
# ### Tokenization
# Tokenization is process of converting Either a sentence, or corpus into tokens
