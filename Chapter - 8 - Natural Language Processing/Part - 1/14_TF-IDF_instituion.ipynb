# %%
import pandas as pd
messages = pd.read_csv(r'D:\GitHub\Data-Science\Chapter - 8 - Natural Language Processing\Part - 1\SMSSpamCollection', sep='\t', names=['label','message'])

# %%
messages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 messages
#
# NameError: name 'messages' is not defined

# %%
# !pip  install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from sklearn.feature_extraction.text import TfidfVectorizer
#
# ModuleNotFoundError: No module named 'sklearn'
