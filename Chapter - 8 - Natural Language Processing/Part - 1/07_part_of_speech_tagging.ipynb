# %% [markdown]
# ### Parts of Speech Tagging

# %%
'Taj Mahal is a beasutiful Monument'
# Out:
# 'Taj Mahal is a beasutiful Monument'

# %%
paragraph =  """
    Article by 'Raimal Raja'
    
    today is the day of losing the greatest human being and beginning of misanthropy 
    (misanthropist who are?? you know them very well, you are all aware of them, about 
    whom I wanted to say I don’t want to mention them )yeah, 
    this is the date, the philanthropist, humanitarian, and ascetic, An Angel of Mercy left this mortal world 
    The richest poor man Abdul Sattar Edhi Sahab. was a Pakistani humanitarian 
    who founded Edhi Foundation which runs the world’s largest volunteer ambulance network. 
    Abdul Sattar Edhi was born in a trader family in 1928 in Bantvan in Gujarat British India, 
    father’s name was Abdul Shakoor Edhi and his mother name was Ghurba Edhi, 
    have one brother Abdul Aziz Edhi.he got married in 1965 to Bilquis. 
    had four children ( two daughters Kubra Edhi and Iimas Edhi 
    and two sons Faisal Edhi and Kutub Edhi )he was considered to be Pakistan’s most respected and legendary 
    figure and in 2013 “the Huffington Post claimed that he might be ” the world’s greatest living 
    humanitarian ” the Huffington post — HuffPost is an American news aggregator 
    and blog with the localized and international edition, the site was launched on 
    May 9, 2005, as the counterpart to the conservative news site Drudge Reporthis son 
    Faisal Edhi said ( i have read this in dawn news reported in Dawn on July 8, 2016) 
    that “he wished to be buried in the same clothes he used to wear, he also wanted to donate his body parts, 
    but the only cornea can be donated as rest of the organ were not in healthy condition 
    (because he died at the age of 88 )the state’s failure to help his struggling family care 
    for his mother paralysed and suffering from mental Heath issues, 
    was his painful and decisive turning point towards philanthropyin the sticky streets in the heart of Karachi, 
    Mr Edhi full of idealism and hope opened his first clinic in 1956what are the golden words of Edhi Sahab,
    he said in his autobiography (A Mirror To The Blind) that “social welfare was my vocation I had to free it”what was 
    the personality of human beings after Prophet Muhammed Mustafa peace be upon him, Edhi was a spiritual quest for 
    the justice Edhi created maternity wards, morgues, orphanages, shelters and homes 
    for the elderly all aimed at helping those who cannot help themselvesEdhi created a charitable empire out of nothing
    Abdul Sattar Edhi’s tireless work has helped save hundreds of thousands of love and 
    show us what it means to be a man who works for the people”Despite all his success, 
    he has always stayed humble, living a simple life in a small house barely large enough to encapsulate his enormous heart” 
    you know he never established a home for his own children he summited, offered surrendered his all life to the nation

"""

# %%
import nltk
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ["\n    Article by 'Raimal Raja'\n\n    today is the day of losing the greatest human being and beginning of misanthropy \n    (misanthropist who are??",
#  'you know them very well, you are all aware of them, about \n    whom I wanted to say I don’t want to mention them )yeah, \n    this is the date, the philanthropist, humanitarian, and ascetic, An Angel of Mercy left this mortal world \n    The richest poor man Abdul Sattar Edhi Sahab.',
#  'was a Pakistani humanitarian \n    who founded Edhi Foundation which runs the world’s largest volunteer ambulance network.',
#  'Abdul Sattar Edhi was born in a trader family in 1928 in Bantvan in Gujarat British India, \n    father’s name was Abdul Shakoor Edhi and his mother name was Ghurba Edhi, \n    have one brother Abdul Aziz Edhi.he got married in 1965 to Bilquis.',
#  'had four children ( two daughters Kubra Edhi and Iimas Edhi \n    and two sons Faisal Edhi and Kutub Edhi )he was considered to be Pakistan’s most respected and legendary \n    figure and in 2013 “the Huffington Post claimed that he might be ” the world’s greatest living \n    humanitarian ” the Huffington post — HuffPost is an American news aggregator \n    and blog with the localized and international edition, the site was launched on \n    May 9, 2005, as the counterpart to the conservative news site Drudge Reporthis son \n    Faisal Edhi said ( i have read this in dawn news reported in Dawn on July 8, 2016) \n    that “he wished to be buried in the same clothes he used to wear, he also wanted to donate his body parts, \n    but the only cornea can be donated as rest of the organ were not in healthy condition \n    (because he died at the age of 88 )the state’s failure to help his struggling family care \n    for his mother paralysed and suffering from mental Heath issues, \n    was his painful and decisive turning point towards philanthropyin the sticky streets in the heart of Karachi, \n    Mr Edhi full of idealism and hope opened his first clinic in 1956what are the golden words of Edhi Sahab,\n    he said in his autobiography (A Mirror To The Blind) that “social welfare was my vocation I had to free it”what was \n    the personality of human beings after Prophet Muhammed Mustafa peace be upon him, Edhi was a spiritual quest for \n    the justice Edhi created maternity wards, morgues, orphanages, shelters and homes \n    for the elderly all aimed at helping those who cannot help themselvesEdhi created a charitable empire out of nothing\n    Abdul Sattar Edhi’s tireless work has helped save hundreds of thousands of love and \n    show us what it means to be a man who works for the people”Despite all his success, \n    he has always stayed humble, living a simple life in a small house barely large enough to encapsulate his enormous heart” \n    you know he never established a home for his own children he summited, offered surrendered his all life to the nation']

# %% [markdown]
# ### We will find the pos tag

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Professor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Professor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in set(stopwords.words('english'))]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Article', 'NNP'), ("'Raimal", 'POS'), ("Raja'", 'NNP'), ('today', 'NN'), ('day', 'NN'), ('losing', 'VBG'), ('greatest', 'JJS'), ('human', 'JJ'), ('beginning', 'VBG'), ('misanthropy', 'NN'), ('(', '('), ('misanthropist', 'VB'), ('?', '.'), ('?', '.')]
# [('know', 'RB'), ('well', 'RB'), (',', ','), ('aware', 'JJ'), (',', ','), ('I', 'PRP'), ('wanted', 'VBD'), ('say', 'VBP'), ('I', 'PRP'), ('’', 'VBP'), ('want', 'JJ'), ('mention', 'NN'), (')', ')'), ('yeah', 'NN'), (',', ','), ('date', 'NN'), (',', ','), ('philanthropist', 'NN'), (',', ','), ('humanitarian', 'JJ'), (',', ','), ('ascetic', 'JJ'), (',', ','), ('An', 'DT'), ('Angel', 'NNP'), ('Mercy', 'NNP'), ('left', 'VBD'), ('mortal', 'JJ'), ('world', 'NN'), ('The', 'DT'), ('richest', 'JJS'), ('poor', 'JJ'), ('man', 'NN'), ('Abdul', 'NNP'), ('Sattar', 'NNP'), ('Edhi', 'NNP'), ('Sahab', 'NNP'), ('.', '.')]
# [('Pakistani', 'NNP'), ('humanitarian', 'NN'), ('founded', 'VBD'), ('Edhi', 'NNP'), ('Foundation', 'NNP'), ('runs', 'VBZ'), ('world', 'NN'), ('’', 'NN'), ('largest', 'JJS'), ('volunteer', 'NN'), ('ambulance', 'NN'), ('network', 'NN'), ('.', '.')]
# [('Abdul', 'NNP'), ('Sattar', 'NNP'), ('Edhi', 'NNP'), ('born', 'VBD'), ('trader', 'NN'), ('family', 'NN'), ('1928', 'CD'), ('Bantvan', 'NNP'), ('Gujarat', 'NNP'), ('British', 'NNP'), ('India', 'NNP'), (',', ','), ('father', 'RB'), ('’', 'JJ'), ('name', 'NN'), ('Abdul', 'NNP'), ('Shakoor', 'NNP'), ('Edhi', 'NNP'), ('mother', 'NN'), ('name', 'NN'), ('Ghurba', 'NNP'), ('Edhi', 'NNP'), (',', ','), ('one', 'CD'), ('brother', 'NN'), ('Abdul', 'NNP'), ('Aziz', 'NNP'), ('Edhi.he', 'NNP'), ('got', 'VBD'), ('married', 'JJ'), ('1965', 'CD'), ('Bilquis', 'NNP'), ('.', '.')]
# [('four', 'CD'), ('children', 'NNS'), ('(', '('), ('two', 'CD'), ('daughters', 'NNS'), ('Kubra', 'NNP'), ('Edhi', 'NNP'), ('Iimas', 'NNP'), ('Edhi', 'NNP'), ('two', 'CD'), ('sons', 'NNS'), ('Faisal', 'NNP'), ('Edhi', 'NNP'), ('Kutub', 'NNP'), ('Edhi', 'NNP'), (')', ')'), ('considered', 'VBD'), ('Pakistan', 'NNP'), ('’', 'NNP'), ('respected', 'VBD'), ('legendary', 'JJ'), ('figure', 'NN'), ('2013', 'CD'), ('“', 'NNP'), ('Huffington', 'NNP'), ('Post', 'NNP'), ('claimed', 'VBD'), ('might', 'MD'), ('”', 'VB'), ('world', 'NN'), ('’', 'NN'), ('greatest', 'JJS'), ('living', 'NN'), ('humanitarian', 'JJ'), ('”', 'NNP'), ('Huffington', 'NNP'), ('post', 'NN'), ('—', 'NN'), ('HuffPost', 'NNP'), ('American', 'NNP'), ('news', 'NN'), ('aggregator', 'NN'), ('blog', 'NN'), ('localized', 'VBD'), ('international', 'JJ'), ('edition', 'NN'), (',', ','), ('site', 'NN'), ('launched', 'VBN'), ('May', 'NNP'), ('9', 'CD'), (',', ','), ('2005', 'CD'), (',', ','), ('counterpart', 'VBP'), ('conservative', 'JJ'), ('news', 'NN'), ('site', 'NN'), ('Drudge', 'NNP'), ('Reporthis', 'NNP'), ('son', 'NN'), ('Faisal', 'NNP'), ('Edhi', 'NNP'), ('said', 'VBD'), ('(', '('), ('read', 'JJ'), ('dawn', 'NN'), ('news', 'NN'), ('reported', 'VBD'), ('Dawn', 'NNP'), ('July', 'NNP'), ('8', 'CD'), (',', ','), ('2016', 'CD'), (')', ')'), ('“', 'FW'), ('wished', 'VBD'), ('buried', 'VBN'), ('clothes', 'NNS'), ('used', 'VBD'), ('wear', 'NN'), (',', ','), ('also', 'RB'), ('wanted', 'VBD'), ('donate', 'NN'), ('body', 'NN'), ('parts', 'NNS'), (',', ','), ('cornea', 'NN'), ('donated', 'VBD'), ('rest', 'JJS'), ('organ', 'JJ'), ('healthy', 'JJ'), ('condition', 'NN'), ('(', '('), ('died', 'JJ'), ('age', 'NN'), ('88', 'CD'), (')', ')'), ('state', 'NN'), ('’', 'JJ'), ('failure', 'NN'), ('help', 'NN'), ('struggling', 'VBG'), ('family', 'NN'), ('care', 'NN'), ('mother', 'NN'), ('paralysed', 'VBD'), ('suffering', 'VBG'), ('mental', 'JJ'), ('Heath', 'NNP'), ('issues', 'NNS'), (',', ','), ('painful', 'JJ'), ('decisive', 'JJ'), ('turning', 'NN'), ('point', 'NN'), ('towards', 'NNS'), ('philanthropyin', 'VBP'), ('sticky', 'JJ'), ('streets', 'NNS'), ('heart', 'NN'), ('Karachi', 'NNP'), (',', ','), ('Mr', 'NNP'), ('Edhi', 'NNP'), ('full', 'JJ'), ('idealism', 'NN'), ('hope', 'NN'), ('opened', 'VBD'), ('first', 'JJ'), ('clinic', 'JJ'), ('1956what', 'CD'), ('golden', 'JJ'), ('words', 'NNS'), ('Edhi', 'NNP'), ('Sahab', 'NNP'), (',', ','), ('said', 'VBD'), ('autobiography', 'NN'), ('(', '('), ('A', 'DT'), ('Mirror', 'NN'), ('To', 'TO'), ('The', 'DT'), ('Blind', 'NNP'), (')', ')'), ('“', 'VBP'), ('social', 'JJ'), ('welfare', 'NN'), ('vocation', 'NN'), ('I', 'PRP'), ('free', 'VBP'), ('”', 'JJ'), ('personality', 'NN'), ('human', 'JJ'), ('beings', 'NNS'), ('Prophet', 'NNP'), ('Muhammed', 'NNP'), ('Mustafa', 'NNP'), ('peace', 'NN'), ('upon', 'NN'), (',', ','), ('Edhi', 'NNP'), ('spiritual', 'JJ'), ('quest', 'JJS'), ('justice', 'NN'), ('Edhi', 'NNP'), ('created', 'VBD'), ('maternity', 'NN'), ('wards', 'NNS'), (',', ','), ('morgues', 'NNS'), (',', ','), ('orphanages', 'NNS'), (',', ','), ('shelters', 'NNS'), ('homes', 'NNS'), ('elderly', 'RB'), ('aimed', 'VBN'), ('helping', 'VBG'), ('help', 'NN'), ('themselvesEdhi', 'NN'), ('created', 'VBD'), ('charitable', 'JJ'), ('empire', 'NN'), ('nothing', 'NN'), ('Abdul', 'NNP'), ('Sattar', 'NNP'), ('Edhi', 'NNP'), ('’', 'NNP'), ('tireless', 'NN'), ('work', 'NN'), ('helped', 'VBD'), ('save', 'VB'), ('hundreds', 'NNS'), ('thousands', 'NNS'), ('love', 'VBP'), ('show', 'VBP'), ('us', 'PRP'), ('means', 'VBZ'), ('man', 'NN'), ('works', 'VBZ'), ('people', 'NNS'), ('”', 'NNP'), ('Despite', 'IN'), ('success', 'NN'), (',', ','), ('always', 'RB'), ('stayed', 'VBN'), ('humble', 'JJ'), (',', ','), ('living', 'VBG'), ('simple', 'JJ'), ('life', 'NN'), ('small', 'JJ'), ('house', 'NN'), ('barely', 'RB'), ('large', 'JJ'), ('enough', 'RB'), ('encapsulate', 'VBP'), ('enormous', 'JJ'), ('heart', 'NN'), ('”', 'NN'), ('know', 'VBP'), ('never', 'RB'), ('established', 'VBN'), ('home', 'NN'), ('chi ...

# %%
string = '''Taj Mahal is a beautiful monument'''
token = [nltk.sent_tokenize(word, language='english') for word in string]

# %%
nltk.pos_tag_sents(token)
# Out:
# [[('T', 'NN')],
#  [('a', 'DT')],
#  [('j', 'NN')],
#  [],
#  [('M', 'NN')],
#  [('a', 'DT')],
#  [('h', 'NN')],
#  [('a', 'DT')],
#  [('l', 'NN')],
#  [],
#  [('i', 'NN')],
#  [('s', 'NN')],
#  [],
#  [('a', 'DT')],
#  [],
#  [('b', 'NN')],
#  [('e', 'NN')],
#  [('a', 'DT')],
#  [('u', 'NN')],
#  [('t', 'NN')],
#  [('i', 'NN')],
#  [('f', 'NN')],
#  [('u', 'NN')],
#  [('l', 'NN')],
#  [],
#  [('m', 'NN')],
#  [('o', 'NN')],
#  [('n', 'NN')],
#  [('u', 'NN')],
#  [('m', 'NN')],
#  [('e', 'NN')],
#  [('n', 'NN')],
#  [('t', 'NN')]]

# %%
list_words = 'Taj Mahal is a beautiful monument'.split()
nltk.pos_tag(list_words)
# Out:
# [('Taj', 'NNP'),
#  ('Mahal', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('beautiful', 'JJ'),
#  ('monument', 'NN')]

# %%
nltk.pos_tag('taj is a beautiful monument'.split())
# Out:
# [('taj', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('beautiful', 'JJ'),
#  ('monument', 'NN')]
