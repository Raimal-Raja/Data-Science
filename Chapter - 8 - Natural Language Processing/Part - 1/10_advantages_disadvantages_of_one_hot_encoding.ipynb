# %% [markdown]
# ## Advantages
# - easy to implement with python
# - using sklearn OneHotEncoding class
#
#
# ## Disadvantages
# - sparse martrix overfitting
# - ML algorithim fixed size input
# - no samantic meaning is getting captured
# - out of vocabulary (OOV)
