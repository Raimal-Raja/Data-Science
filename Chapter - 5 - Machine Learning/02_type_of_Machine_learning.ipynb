# %% [markdown]
# ### Types of Machine Leaning
# There are four types of Machine Learning
# 1. Supervised Machine
#     - Adaboost
#     - Xboost
#     - Decision Tree
#     - KNN
# 2. Unsupervised Machine Learning
#     - K-Mean
#     - Hirarical Clustering
# 3. Reinforcement Learning
#     - reward and penalty
# 4. Semi-supervised learning (sup + unsup)
