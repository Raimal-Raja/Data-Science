# %% [markdown]
# ### K-nearest neighbors algorithm (KNN)
#
# - it is a supervised machine learning algorithm
# - This algorithm can be used to solve both classification and regression problem statements.
#
# - the number of nearest neighbors to a new unknown variable that has to be predicated or classified is denoted the symbol 'k'
