# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in d:\github\data-science\.env\lib\site-packages (6.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in d:\github\data-science\.env\lib\site-packages (from plotly) (2.18.0)
# Requirement already satisfied: packaging in d:\github\data-science\.env\lib\site-packages (from plotly) (25.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in d:\github\data-science\.env\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\github\data-science\.env\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\github\data-science\.env\lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\github\data-science\.env\lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in d:\github\data-science\.env\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\github\data-science\.env\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\github\data-science\.env\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\github\data-science\.env\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\github\data-science\.env\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\github\data-science\.env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in d:\github\data-science\.env\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X,y =  make_regression(n_samples=100,n_features=2,n_informative = 2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':x[:,0],'feature2':x[:,1],'target':'y'})

# %%
df.head(2)
# Out:
#    feature1  feature2 target
# 0 -0.091075 -0.699119      y
# 1  0.041861 -0.865751      y

# %%
fig = px.scatter_3d(df,x='feature1',y='feature2',z='target')
fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state=2)

# %%
len(X_train)
# Out:
# 80

# %%
len(X_test)
# Out:
# 20

# %%
from sklearn.linear_model import LinearRegression 

lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([ -29.5057035 ,  -60.43501577,   82.65289651,   19.1622661 ,
#          -5.07569095,   75.87419019,  -11.6265104 ,   35.42651985,
#         -51.37602552,  -51.20778902,  -34.73885805,   15.12313906,
#         -64.70520415,   81.67094913,  -68.69520116, -100.52128513,
#          -7.0656347 ,  -67.5271993 ,  -60.12761871,  -17.19398982])

# %%
y_test
# Out:
# array([ -18.64253531,  -46.56356357,   51.01519188,  -38.68155524,
#          95.32875297,   84.62318886, -108.6773676 ,   72.81158834,
#         -30.12644796,  -20.98377553,    7.10765194,   47.43241356,
#         -83.98320721,   49.67031712,  -32.71713137,  -30.22364682,
#         -30.10138066,   27.99397454,    4.75663485,   24.44005532])

# %%
print('MAE: ', mean_absolute_error(y_test,y_pred))
print('MSE: ',mean_squared_error(y_test,y_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_test,y_pred)))
print('R2_score: ',r2_score(y_test,y_pred))
# Out:
# MAE:  43.30322259150317
# MSE:  2651.080198777837
# RMSE:  51.488641453992905
# R2_score:  0.07640232234973066
